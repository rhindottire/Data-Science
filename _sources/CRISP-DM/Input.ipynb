# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ## Data Integration

# %% [markdown]
# ## Data Reduction

# %% [markdown]
# ## Data Formatting

# %% [markdown]
# ## Data Splitting
