# %% [markdown]
# # Business Understanding

# %% [markdown]
# ## Define the Problem

# %% [markdown]
# ## Set Objectives

# %% [markdown]
# ## Identify Stakeholders

# %% [markdown]
# ## Define Success Criteria
