# %% [markdown]
# # Tugas 2

# %% [markdown]
# ## Iris Dataset

# %%
import pandas as pd
from IPython.display import display

# %%
iris = pd.read_excel('../Assets/data/iris/iris.xlsx')
iris.to_csv('../Assets/data/courseworks/2/iris.csv', index=False)
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            150 non-null    int64
#  1   Class         150 non-null    object
#  2   sepal length  150 non-null    float64
#  3   sepal width   150 non-null    float64
#  4   petal length  150 non-null    float64
#  5   petal width   150 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
display(iris.head())
# Out:
#    id        Class  sepal length  sepal width  petal length  petal width
# 0   1  Iris-setosa           5.1          3.5           1.4          0.2
# 1   2  Iris-setosa           4.9          3.0           1.4          0.2
# 2   3  Iris-setosa           4.7          3.2           1.3          0.2
# 3   4  Iris-setosa           4.6          3.1           1.5          0.2
# 4   5  Iris-setosa           5.0          3.6           1.4          0.2

# %% [markdown]
# ## Database Local

# %% [markdown]
# ### Laragon

# %% [markdown]
# ![Laragon](../Assets/img/tugas2/laragon.png)

# %% [markdown]
# ### MySQL Database

# %% [markdown]
# ![MySQL DB](../Assets/img/tugas2/mysql-DB.png)

# %% [markdown]
# ### PostgreSQL Database

# %% [markdown]
# ![PostgreSQL DB](../Assets/img/tugas2/postgres-DB.png)

# %% [markdown]
# ## Power-BI

# %% [markdown]
# ### Connect Database

# %% [markdown]
# ![Power-BI Connect DB](../Assets/img/tugas2/connect-DB.png)

# %% [markdown]
# ### Column Schema

# %% [markdown]
# ```python
# let
#     Source = iris_dataset iris,
#     SchemaTable = Table.Schema(Source),
#     SelectColumns = Table.SelectColumns(SchemaTable, {"Name", "TypeName", "Kind"}),
#     AddDescription = Table.AddColumn(SelectColumns, "Description", each
#         "Tipe Data: " & [TypeName] &
#         "(Kind: " & Text.From([Kind]) & ") - Total Rows: " &
#         Text.From(Table.RowCount(Source)) & " (No Nulls)"
#     )
# in
#     AddDescription
# ```
#
# ![Column Schema](../Assets/img/tugas2/data-type.png)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Sum of Columns

# %% [markdown]
# ![Sum of Columns](../Assets/img/tugas2/sum-of-columns.png)

# %% [markdown]
# ### Average of Columns

# %% [markdown]
# ![Average of Columns](../Assets/img/tugas2/average-of-columns.png)
