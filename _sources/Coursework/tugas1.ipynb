# %% [markdown]
# # Tugas 1

# %% [markdown]
# ## Data Source:
# - [Iris dataset](https://www.kaggle.com/datasets/himanshunakrani/iris-dataset)
# - [Mobiles & laptop Sales Data](https://www.kaggle.com/datasets/vinothkannaece/mobiles-and-laptop-sales-data)

# %%
import kagglehub, shutil, os, pandas as pd

dst = "../Assets/data/courseworks/1"
os.makedirs(dst, exist_ok=True)

# %%
iris = kagglehub.dataset_download("himanshunakrani/iris-dataset")
sales = kagglehub.dataset_download("vinothkannaece/mobiles-and-laptop-sales-data")

for src in [iris, sales]:
    for file in os.listdir(src):
        src_file = os.path.join(src, file)

        if os.path.isfile(src_file):
            shutil.copy2(src_file, dst)

print("Files in destination:", os.listdir(dst))
# Out:
# Files in destination: ['iris.csv', 'mobile_sales_data.csv']

# %% [markdown]
# ## Apps Install

# %% [markdown]
# ![Apps](../Assets/img/tugas1/install.png)

# %% [markdown]
# ### 1. Orange

# %% [markdown]
# ![Orange](../Assets/img/tugas1/orange.png)

# %% [markdown]
# ### 2. Exploratory

# %% [markdown]
# ![Exploratory](../Assets/img/tugas1/exploratory.png)

# %% [markdown]
# ### 3. Power BI

# %% [markdown]
# ![Power-BI](../Assets/img/tugas1/power-bi.png)

# %% [markdown]
# ## Setup Jupyter Book

# %% [markdown]
# ![Jupyter Book](../Assets/img/tugas1/jupyter-book.png)
