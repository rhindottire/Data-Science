# %%
import pandas as pd
df1= pd.read_csv('../data/csv/all-task-3-detailed-reviews.csv')
df2 = pd.read_csv('../data/csv/all-task-3-featured-reviews.csv')
df3 = pd.read_csv('../data/csv/all-task-3-overview.csv')
df4 = pd.read_csv('../data/csv/all-task-3.csv')

# %%
df1.head()
# Out:
#                       place_id     place_name  \
# 0  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 1  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 2  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 3  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 4  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
#
#                                            review_id  \
# 0  Ci9DQUlRQUNvZENodHljRjlvT2paRWVubEVTSE5aTFZaVV...
# 1               ChdDSUhNMG9nS0VJQ0FnTUNZc05iSWpRRRAB
# 2                ChZDSUhNMG9nS0VJQ0FnSURUMjgyN0p3EAE
# 3               ChdDSUhNMG9nS0VJQ0FnSUMxNGFtV3NnRRAB
# 4               ChdDSUhNMG9nS0VJQ0FnSUQ2a09DNGdnRRAB
#
#                                          review_link                  name  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...          abdul kholik
# 1  https://www.google.com/maps/reviews/data=!4m8!...  Nashra kamilah. Amel
# 2  https://www.google.com/maps/reviews/data=!4m8!...            Supriyanto
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6622 entries, 0 to 6621
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   place_id                             6622 non-null   object
#  1   place_name                           6622 non-null   object
#  2   review_id                            6622 non-null   object
#  3   review_link                          6622 non-null   object
#  4   name                                 6622 non-null   object
#  5   reviewer_id                          6622 non-null   object
#  6   reviewer_profile                     6622 non-null   object
#  7   rating                               6622 non-null   int64
#  8   review_text                          3455 non-null   object
#  9   published_at                         6622 non-null   object
#  10  published_at_date                    6622 non-null   object
# ...

# %%
df2.head()
# Out:
#                       place_id     place_name  \
# 0  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 1  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 2  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 3  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
# 4  ChIJYQIbq0US2C0RoXbX5gkHWUY  Kahoona Beach
#
#                                            review_id  \
# 0               ChdDSUhNMG9nS0VJQ0FnSUQ2a09DNGdnRRAB
# 1  Ci9DQUlRQUNvZENodHljRjlvT2paRWVubEVTSE5aTFZaVV...
# 2                ChZDSUhNMG9nS0VJQ0FnSUNlejZ2NFN3EAE
# 3                ChZDSUhNMG9nS0VJQ0FnSUNCN01mWkhBEAE
# 4               ChdDSUhNMG9nS0VJQ0FnSURSdnVyVzNnRRAB
#
#                                          review_link  \
# 0  https://www.google.com/maps/reviews/data=!4m8!...
# 1  https://www.google.com/maps/reviews/data=!4m8!...
# 2  https://www.google.com/maps/reviews/data=!4m8!...
# 3  https://www.google.com/maps/reviews/data=!4m8!...
# 4  https://www.google.com/maps/reviews/data=!4m8!...
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   place_id                             512 non-null    object
#  1   place_name                           512 non-null    object
#  2   review_id                            512 non-null    object
#  3   review_link                          512 non-null    object
#  4   name                                 512 non-null    object
#  5   reviewer_id                          512 non-null    object
#  6   reviewer_profile                     512 non-null    object
#  7   rating                               512 non-null    int64
#  8   review_text                          471 non-null    object
#  9   published_at                         512 non-null    object
#  10  published_at_date                    512 non-null    object
# ...

# %%
df3.head()
# Out:
#                       place_id                    name description  \
# 0  ChIJYQIbq0US2C0RoXbX5gkHWUY           Kahoona Beach         NaN
# 1  ChIJxWCJ0M4C2C0RVkIRQqMGJHs       Pantai Goa Petapa         NaN
# 2  ChIJCb-H_gM_2C0RotQ5H2cQ_9g  Pantai Siring Kemuning         NaN
# 3  ChIJF_T0zSUD2C0RJFytakQa2VM            Pantai Rindu         NaN
# 4  ChIJuRiSbwAd2C0RDp_Iezqhlmk       Merah Putih Beach         NaN
#
#    is_spending_on_ads  reviews  rating  \
# 0                 NaN       22     4.3
# 1                 NaN      319     4.2
# 2                 NaN      511     4.0
# 3                 NaN     1386     3.7
# 4                 NaN        1     5.0
#
#                                          competitors  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Name: Dermaga Rindu\nLink: https://www.google....
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   place_id               96 non-null     object
#  1   name                   96 non-null     object
#  2   description            13 non-null     object
#  3   is_spending_on_ads     0 non-null      float64
#  4   reviews                96 non-null     int64
#  5   rating                 96 non-null     float64
#  6   competitors            68 non-null     object
#  7   website                11 non-null     object
#  8   phone                  18 non-null     object
#  9   can_claim              52 non-null     float64
#  10  owner_name             68 non-null     object
#  11  owner_profile_link     13 non-null     object
#  12  featured_image         92 non-null     object
#  13  main_category          96 non-null     object
# ...

# %%
df4.head()
# Out:
#                       place_id                    name description  \
# 0  ChIJYQIbq0US2C0RoXbX5gkHWUY           Kahoona Beach         NaN
# 1  ChIJxWCJ0M4C2C0RVkIRQqMGJHs       Pantai Goa Petapa         NaN
# 2  ChIJCb-H_gM_2C0RotQ5H2cQ_9g  Pantai Siring Kemuning         NaN
# 3  ChIJF_T0zSUD2C0RJFytakQa2VM            Pantai Rindu         NaN
# 4  ChIJuRiSbwAd2C0RDp_Iezqhlmk       Merah Putih Beach         NaN
#
#    is_spending_on_ads  reviews  rating  \
# 0                 NaN       22     4.3
# 1                 NaN      319     4.2
# 2                 NaN      511     4.0
# 3                 NaN     1386     3.7
# 4                 NaN        1     5.0
#
#                                          competitors  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{"name":"Dermaga Rindu","link":"https://www.g...
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   place_id               96 non-null     object
#  1   name                   96 non-null     object
#  2   description            13 non-null     object
#  3   is_spending_on_ads     0 non-null      float64
#  4   reviews                96 non-null     int64
#  5   rating                 96 non-null     float64
#  6   competitors            96 non-null     object
#  7   website                11 non-null     object
#  8   phone                  18 non-null     object
#  9   can_claim              52 non-null     float64
#  10  owner                  96 non-null     object
#  11  featured_image         92 non-null     object
#  12  main_category          96 non-null     object
#  13  categories             96 non-null     object
# ...
