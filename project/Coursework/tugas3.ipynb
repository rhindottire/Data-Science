# %% [markdown]
# ## Tugas 3

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## Partitioning the Iris dataset

# %%
iris = pd.read_excel('../data/iris.xlsx')
print(iris.info())
print(iris.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            150 non-null    int64
#  1   Class         150 non-null    object
#  2   sepal length  150 non-null    float64
#  3   sepal width   150 non-null    float64
#  4   petal length  150 non-null    float64
#  5   petal width   150 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None
#    id        Class  sepal length  sepal width  petal length  petal width
# 0   1  Iris-setosa           5.1          3.5           1.4          0.2
# 1   2  Iris-setosa           4.9          3.0           1.4          0.2
# 2   3  Iris-setosa           4.7          3.2           1.3          0.2
# 3   4  Iris-setosa           4.6          3.1           1.5          0.2
# 4   5  Iris-setosa           5.0          3.6           1.4          0.2

# %%
petal = iris[['id', 'Class', 'petal length', 'petal width']]
sepal = iris[['id', 'Class', 'sepal length', 'sepal width']]

os.makedirs('../data/iris', exist_ok=True)
petal.to_csv('../data/iris/petal.csv', index=False)
sepal.to_csv('../data/iris/sepal.csv', index=False)

# %% [markdown]
# ### PostgreSQL Petal

# %% [markdown]
# ![Apps](../img/tugas3/postgres/pgAdmin.png)

# %%
petal = pd.read_csv('../data/iris/petal.csv')
print(petal.info())
print(petal.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            150 non-null    int64
#  1   Class         150 non-null    object
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.8+ KB
# None
#    id        Class  petal length  petal width
# 0   1  Iris-setosa           1.4          0.2
# 1   2  Iris-setosa           1.4          0.2
# 2   3  Iris-setosa           1.3          0.2
# 3   4  Iris-setosa           1.5          0.2
# 4   5  Iris-setosa           1.4          0.2

# %% [markdown]
# ![Apps](../img/tugas3/postgres/power-bi.png)

# %% [markdown]
# ### MySQL Sepal

# %% [markdown]
# ![Apps](../img/tugas3/mysql/phpMyAdmin.png)

# %%
sepal = pd.read_csv('../data/iris/sepal.csv')
print(sepal.info())
print(sepal.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            150 non-null    int64
#  1   Class         150 non-null    object
#  2   sepal length  150 non-null    float64
#  3   sepal width   150 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.8+ KB
# None
#    id        Class  sepal length  sepal width
# 0   1  Iris-setosa           5.1          3.5
# 1   2  Iris-setosa           4.9          3.0
# 2   3  Iris-setosa           4.7          3.2
# 3   4  Iris-setosa           4.6          3.1
# 4   5  Iris-setosa           5.0          3.6

# %% [markdown]
# ![Apps](../img/tugas3/mysql/power-bi.png)

# %% [markdown]
# ## Get data using script

# %% [markdown]
# ```python
# pip install pandas sqlalchemy psycopg2-binary pymysql
# pip install pycaret==3.0.0 --no-build-isolation
#
# import pandas as pd
# from sqlalchemy import create_engine
#
# postgre_engine = create_engine("postgresql+psycopg2://postgres:123@localhost:5432/iris_postgres")
# postgre_query = "SELECT * FROM iris_postgres;"
# postgre_df = pd.read_sql(postgre_query, postgre_engine)
#
# mysql_engine = create_engine("mysql+pymysql://root:@localhost:3306/iris_mysql")
# mysql_query = "SELECT * FROM iris_mysql;"
# mysql_df = pd.read_sql(mysql_query, mysql_engine)
# ```

# %%
import pandas as pd
from sqlalchemy import create_engine

# Koneksi ke MySQL
MYSQL_HOST = "localhost"
MYSQL_PORT = 3306
MYSQL_USER = "root"
MYSQL_PASSWORD = ""
MYSQL_DATABASE = "iris_mysql"

# Koneksi ke PostgreSQL
PG_HOST = "localhost"
PG_PORT = 5432
PG_USER = "postgres"
PG_PASSWORD = "123"
PG_DATABASE = "iris_postgres"

# Gunakan SQLAlchemy untuk koneksi ke MySQL
mysql_engine = create_engine(
    f"mysql+pymysql://{MYSQL_USER}:{MYSQL_PASSWORD}@{MYSQL_HOST}:{MYSQL_PORT}/{MYSQL_DATABASE}"
)

# Gunakan SQLAlchemy untuk koneksi ke PostgreSQL
pg_engine = create_engine(
    f"postgresql+psycopg2://{PG_USER}:{PG_PASSWORD}@{PG_HOST}:{PG_PORT}/{PG_DATABASE}"
)

# Jalankan query
mysql_query = "SELECT * FROM sepal;"
df_mysql = pd.read_sql(mysql_query, mysql_engine)

pg_query = "SELECT * FROM iris_petal;"
df_postgres = pd.read_sql(pg_query, pg_engine)

# Print hasil
print("Data dari MySQL:")
print(df_mysql.head())

print("\nData dari PostgreSQL:")
print(df_postgres.head())
# Out:
# Data dari MySQL:
#    id        Class  sepal_length  sepal_width
# 0   1  Iris-setosa           5.1          3.5
# 1   2  Iris-setosa           4.9          3.0
# 2   3  Iris-setosa           4.7          3.2
# 3   4  Iris-setosa           4.6          3.1
# 4   5  Iris-setosa           5.0          3.6
#
# Data dari PostgreSQL:
#    id        Class  petal_length  petal_width
# 0   1  Iris-setosa           1.4          0.2
# 1   2  Iris-setosa           1.4          0.2
# 2   3  Iris-setosa           1.3          0.2
# 3   4  Iris-setosa           1.5          0.2
# 4   5  Iris-setosa           1.4          0.2
